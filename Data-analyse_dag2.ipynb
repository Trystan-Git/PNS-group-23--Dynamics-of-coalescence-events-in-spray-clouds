# %% [markdown]
# ## Data-analyse dag 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt

from lmfit import models

# %% [markdown]
# ### Data metingen

# %%
dist_noz1 = [20, 21, 22, 26]

av_vol1= [524.45898, 551.078918457, 503.139831543, 535.252624512]

dist_noz2 = [21, 22, 23,31]

av_vol2 = [411.250091553, 410.322662354, 430.225067139, 417.083007813]

# %% [markdown]
# ### Fouten

# %%
err_dist_noz1 = [2, 2, 2, 2]

err_dist_noz2 = [2, 2, 2, 2]

err_av_vol1 = [58.8339271545, 66.5452728271, 51.6724472046, 75.0904388428]

err_av_vol2 = [84.2842636108, 103.050354004, 91.4504470825, 67.0126113892]

# %% [markdown]
# ## Datapunten meting 1

# %%
plt.figure()

plt.errorbar(dist_noz1, av_vol1, xerr=err_dist_noz1, yerr=err_av_vol1, fmt='o')

plt.title(r"Meting 1")
plt.xlabel(r"Distance from nozzle")
plt.ylabel(r"Average droplet volume")
# Out:
# Text(0, 0.5, 'Average droplet volume')

# %% [markdown]
# ## Datapunten meting 2

# %%
plt.figure()

plt.errorbar(dist_noz2, av_vol2, xerr=err_dist_noz2, yerr=err_av_vol2, fmt='o')

plt.title("Meting 2")
plt.xlabel(r"Distance from nozzle")
plt.ylabel(r"Average droplet volume")
# Out:
# Text(0, 0.5, 'Average droplet volume')

# %% [markdown]
# ### Fitfunctie definiëren

# %%
def fitfunctie()
